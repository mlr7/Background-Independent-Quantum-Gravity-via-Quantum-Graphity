# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import networkx as nx

import panel as pn
pn.extension()

import hvplot
import hvplot.networkx as hvnx
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>

# %%
def color_edge(node1=0, node2=1):
    
    g = nx.complete_graph(5)
    pos = nx.circular_layout(g)
    
    #g.add_edge(1,2, color='r', weight=7)
    
    nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)
    
    nx.draw_networkx_edges(g, pos, edgelist=[(node1,node2)],
                       width=8, edge_color="tab:red")
    
    return g

# %%
color_edge(2,4);

# %%
app1 = pn.Column('## App-1', color_edge, align="center")
app1
# Out:
# <pre>Traceback (most recent call last):
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\pyviz_comms\__init__.py&quot;, line 346, in _handle_msg
#     self._on_msg(msg)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\viewable.py&quot;, line 297, in _on_msg
#     doc.unhold()
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\bokeh\document\document.py&quot;, line 799, in unhold
#     self.callbacks.unhold()
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\bokeh\document\callbacks.py&quot;, line 396, in unhold
#     self.trigger_on_change(event)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\bokeh\document\callbacks.py&quot;, line 373, in trigger_on_change
#     invoke_with_curdoc(doc, event.callback_invoker)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\bokeh\document\callbacks.py&quot;, line 408, in invoke_with_curdoc
#     return f()
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\bokeh\util\callback_manager.py&quot;, line 191, in invoke
#     callback(attr, old, new)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\reactive.py&quot;, line 405, in _comm_change
#     state._handle_exception(e)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\io\state.py&quot;, line 399, in _handle_exception
#     raise exception
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\reactive.py&quot;, line 403, in _comm_change
#     self._schedule_change(doc, comm)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\reactive.py&quot;, line 385, in _schedule_change
#     self._change_event(doc)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\reactive.py&quot;, line 381, in _change_event
#     self._process_events(events)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\reactive.py&quot;, line 319, in _process_events
#     self.param.update(**self_events)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\param\parameterized.py&quot;, line 1898, in update
#     self_._batch_call_watchers()
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\param\parameterized.py&quot;, line 2059, in _batch_call_watchers
#     self_._execute_watcher(watcher, events)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\param\parameterized.py&quot;, line 2021, in _execute_watcher
#     watcher.fn(*args, **kwargs)
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\panel\interact.py&quot;, line 138, in update_pane
#     new_object = self.object(**self.kwargs)
#   File &quot;C:\Users\m85302\AppData\Local\Temp\ipykernel_26068\1348879146.py&quot;, line 10, in color_edge
#     nx.draw_networkx_edges(g, pos, edgelist=[(node1,node2)],
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\networkx\drawing\nx_pylab.py&quot;, line 702, in draw_networkx_edges
#     edge_pos = np.asarray([(pos[e[0]], pos[e[1]]) for e in edgelist])
#   File &quot;C:\ProgramData\Anaconda2021_05\envs\panel_2\lib\site-packages\networkx\drawing\nx_pylab.py&quot;, line 702, in &lt;listcomp&gt;
#     edge_pos = np.asarray([(pos[e[0]], pos[e[1]]) for e in edgelist])
# KeyError: -1
# </pre>
# Column(align='center')
#     [0] Markdown(str)
#     [1] Column
#         [0] Column
#             [0] IntSlider(name='node1')
#             [1] IntSlider(end=3, name='node2', start=-1, value=1)
#         [1] Row
#             [0] Str(Graph, name='interactive00809')

# %% [markdown]
# ### Older Code Below

# %%
def complete_graph(pts=15):
    
    g = nx.complete_graph(pts)
    pos = nx.circular_layout(g)
    
    return hvnx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)

# %%
g = nx.complete_graph(15)
pos = nx.circular_layout(g)
#g.add_edge(1,2, color='r', weight=70)

#colors = nx.get_edge_attributes(g, 'color').values()
#colors
#nx.draw(g, edge_color=colors)

nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)

nx.draw_networkx_edges(g, pos, edgelist=[(4,12)],
                       width=8, edge_color="tab:red")

# %%
g = nx.complete_graph(15)
pos = nx.circular_layout(g)
#g.add_edge(1,2, color='r', weight=70)

#colors = nx.get_edge_attributes(g, 'color').values()
#colors
#nx.draw(g, edge_color=colors)

nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)

nx.draw_networkx_edges(g, pos, edgelist=[(4,12)],
                       width=8, edge_color="tab:red")

nx.draw_networkx_edges(g, pos, edgelist=[(9,0)],
                       width=8, edge_color="tab:red")

# %%
def complete_graph_coloredge(pts=15, edgelist1=[(1,2)]):
    
    g = nx.complete_graph(pts)
    pos = nx.circular_layout(g)
    
    #g.add_edge(1,2, color='r', weight=7)
    
    nx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)
    
    nx.draw_networkx_edges(g, pos, edgelist=edgelist1, # edgelist=[(1,2)]
                       width=8, edge_color="tab:red")
    
    #return hvnx.draw(g, pos, node_size=1000,node_color="skyblue", with_labels=True)
    return g

# %%
complete_graph_coloredge(5, [(2,4)]);

# %%
d1 = complete_graph(5)
d2 = color_edge(d1, 1,2)
d1

# %%
points = pn.widgets.IntSlider(name = 'nodes', value=15,  start=1, end=30)
interactive = pn.bind(complete_graph, pts=points)

# %%
graphity_app1 = pn.Column('## Graphity App-1', points, interactive, align="center")
graphity_app1

# %%
graphity_app1.show()
